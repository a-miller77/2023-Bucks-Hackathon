# %% [markdown]
# # Creating a Dataframe of Just Nading Matchups #
#
# Used for finding matchups that were only defender X vs Samuel Nading
#
# Data Stored in only_nading_matchups.csv

# %%
import pandas as pd

df = pd.read_csv('base_data/hackathon_data_basketball_2023.csv')

df
# Out:
#         player_defMatchup_a      player_off_a  player_off_ht  \
# 0           Lapointe, Uriah   Rinhart, Jordan             82
# 1           Lapointe, Uriah     Weeks, Robert             74
# 2           Lapointe, Uriah     Polson, Aiden             81
# 3           Lapointe, Uriah      Smith, Aaron             80
# 4           Lapointe, Uriah    Garcia, Daniel             82
# ...                     ...               ...            ...
# 343418  Hyden-Terry, Victor   Awtrey, Derrick             77
# 343419  Hyden-Terry, Victor  Failing, Leonard             78
# 343420  Hyden-Terry, Victor  Duran, Sebastian             83
# 343421  Hyden-Terry, Victor      Jones, James             79
# 343422  Hyden-Terry, Victor    White, Brannon             84
#
#         player_defMatchup_ht  poss  ptsScored_team  fga   fg  fga3  fg3  ...  \
# 0                         81     1               0  NaN  NaN   NaN  NaN  ...
# ...

# %%
nading_only = df[df['player_off_a'] == "Nading, Samuel"]

nading_only

#nading_only.to_csv('filtered_sets/only_nading_matchups.csv")
# Out:
#         player_defMatchup_a    player_off_a  player_off_ht  \
# 511         Lapointe, Uriah  Nading, Samuel             79
# 874         Lapointe, Uriah  Nading, Samuel             79
# 883         Lapointe, Uriah  Nading, Samuel             79
# 1339        Lapointe, Uriah  Nading, Samuel             79
# 1575        Lapointe, Uriah  Nading, Samuel             79
# ...                     ...             ...            ...
# 341872  Hyden-Terry, Victor  Nading, Samuel             79
# 342664  Hyden-Terry, Victor  Nading, Samuel             79
# 342778  Hyden-Terry, Victor  Nading, Samuel             79
# 343287  Hyden-Terry, Victor  Nading, Samuel             79
# 343305  Hyden-Terry, Victor  Nading, Samuel             79
#
#         player_defMatchup_ht  poss  ptsScored_team  fga   fg  fga3  fg3  ...  \
# 511                       81     1               0  NaN  NaN   NaN  NaN  ...
# 874                       81     1               0  NaN  NaN   NaN  NaN  ...
# ...
