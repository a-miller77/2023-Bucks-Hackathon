# %%
#Created By Elias Vera-Jimenez

# Base Imports
import pandas as pd
import numpy as np

df = pd.read_csv('filtered_sets/nading_matchup_averages.csv') # Accessing the CSV with only nading matchups

# %%
# Storing the names & height of all of the players that are taller than nading
taller_than_nading = df[df["player_defMatchup_ht"] > 81 ]

taller_than_nading
# Out:
#     Unnamed: 0  index  player_defMatchup_a  player_defMatchup_ht  \
# 4            4     92      Rosser, Michael                    82
# 17          17    427         Dalke, David                    83
# 21          21    585       Mariman, Isaac                    84
# 45          45   1058        Romero, Roger                    83
# 50          50   1114   Benally, Kaldurion                    85
# 51          51   1124        House, Steven                    84
# 59          59   1284      Outhouse, Brent                    83
# 65          65   1351       Thomas, Joseph                    84
# 71          71   1403       Martinez, Luke                    85
# 75          75   1468  Good Wind, Cheyenne                    83
# 81          81   1555     Dupree, Jeremiah                    82
# 87          87   1662  Hyden-Terry, Victor                    84
#
#     avg_ptsScored_team  avg_fga  avg_fg  avg_fga3  avg_fg3  avg_qSQ  ...  \
# ...

# %%
# Storing the names & heights of all of the players that are around the same or the same height as Nading
shorter_than_nading_raw = df[df["player_defMatchup_ht"].between(77,81)]

shorter_than_nading_raw = shorter_than_nading_raw[["player_defMatchup_a","player_defMatchup_ht"]]

shorter_than_nading = shorter_than_nading_raw.drop_duplicates()

shorter_than_nading
# Out:
#       player_defMatchup_a  player_defMatchup_ht
# 8          House, Brandyn                    76
# 22       Morser, Cheyenne                    79
# 147         Chavez, Jakob                    78
# 149          Orr, Jeffrey                    79
# 159       Thomas, Matthew                    79
# 213       Herrera, Austin                    78
# 266      Hartmann, Miguel                    76
# 350           Red, Taylor                    78
# 363      Oscarson, Jeremy                    74
# 367           Lial, Tyler                    79
# 378          Diaz, Joshua                    77
# 417      Mattice, Phillip                    77
# 440          Nunley, Luke                    76
# 535    Blaeholder, Elijah                    76
# 591      Vialpando, David                    75
# 596          Dedios, Eric                    73
# 642      Hammond, Brandyn                    78
# 673     Vialpando, Samuel                    78
# 677         Ortiz, Marcus                    76
# ...
